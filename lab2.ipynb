# %% [markdown]
# ## Deadline
# Wednesday October 25, 2017 at 11:59PM
#
# ## Important Notes
# * Make sure you push on GitHub your Notebook with all the cells already evaluated (i.e., you don't want your colleagues to generate unnecessary Web traffic during the peer review)
# * Don't forget to add a textual description of your thought process, the assumptions you made, and the solution you plan to implement!
# * Please write all your comments in English, and use meaningful variable names in your code.
#
# ## Background
# In this homework we will extract interesting information from www.topuniversities.com and www.timeshighereducation.com, two platforms that maintain a global ranking of worldwide universities. This ranking is not offered as a downloadable dataset, so you will have to find a way to scrape the information we need!
# You are not allowed to download manually the entire ranking -- rather you have to understand how the server loads it in your browser. For this task, Postman with the Interceptor extension can help you greatly. We recommend that you watch this [brief tutorial](https://www.youtube.com/watch?v=jBjXVrS8nXs&list=PLM-7VG-sgbtD8qBnGeQM5nvlpqB_ktaLZ&autoplay=1) to understand quickly how to use it.

# %% [markdown]
# ## Assignment
# 1. Obtain the 200 top-ranking universities in www.topuniversities.com ([ranking 2018](https://www.topuniversities.com/university-rankings/world-university-rankings/2018)). In particular, extract the following fields for each university: name, rank, country and region, number of faculty members (international and total) and number of students (international and total). Some information is not available in the main list and you have to find them in the [details page](https://www.topuniversities.com/universities/ecole-polytechnique-f矇d矇rale-de-lausanne-epfl).
# Store the resulting dataset in a pandas DataFrame and answer the following questions:
# - Which are the best universities in term of: (a) ratio between faculty members and students, (b) ratio of international students?
# - Answer the previous question aggregating the data by (c) country and (d) region.
#
# Plot your data using bar charts and describe briefly what you observed.
#
# 2. Obtain the 200 top-ranking universities in www.timeshighereducation.com ([ranking 2018](http://timeshighereducation.com/world-university-rankings/2018/world-ranking)). Repeat the analysis of the previous point and discuss briefly what you observed.
#
# 3. Merge the two DataFrames created in questions 1 and 2 using university names. Match universities' names as well as you can, and explain your strategy. Keep track of the original position in both rankings.
#
# 4. Find useful insights in the data by performing an exploratory analysis. Can you find a strong correlation between any pair of variables in the dataset you just created? Example: when a university is strong in its international dimension, can you observe a consistency both for students and faculty members?
#
# 5. Can you find the best university taking in consideration both rankings? Explain your approach.
#
# Hints:
# - Keep your Notebook clean and don't print the verbose output of the requests if this does not add useful information for the reader.
# - In case of tie, use the order defined in the webpage.

# %% [markdown]
# # Import Libraries

# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import seaborn
# %matplotlib inline

# %% [markdown]
# # Part1. QS Ranking

# %%
URL = 'https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051_indicators.txt'
r = requests.get(URL)

# %%
universites_info = r.json()['data'][0:200]

# links
university_links = [BeautifulSoup(university['uni'], 'html.parser').find('a') for university in universites_info]

# name as index
data_qs = pd.DataFrame([university_link.text for university_link in university_links], columns = ['university'])

# rank
data_qs['rank'] = [(int)(university['overall_rank']) for university in universites_info]
# country
data_qs['country'] = [university['location'] for university in universites_info]
# region
data_qs['region'] = [university['region'] for university in universites_info]

# %% [markdown]
# ### 1. extract the following fields for each university: name, rank, country and region, number of faculty members (international and total) and number of students (international and total)

# %%
def getData(webpage, label):
    try:
        number = (int)(webpage.find('div', class_ = label).find('div', class_ = 'number').text.replace(',',''))
    except AttributeError:
        number = 0
    return number

# access details of each university
header = 'https://www.topuniversities.com'
web_addresses = [header + university_link.get('href') for university_link in university_links]
university_pages = [requests.get(web_address) for web_address in web_addresses] 
university_details = [BeautifulSoup(page.text, 'html.parser') for page in university_pages] 

# number of international students
data_qs['international students'] = [getData(page, 'total inter') for page in university_details]
# number of total students
data_qs['total students'] = [getData(page, 'total student') for page in university_details]
# number of foreign faculty
data_qs['international faculties'] = [getData(page, 'inter faculty') for page in university_details]
# number of total faculty
data_qs['total faculties'] = [getData(page, 'total faculty') for page in university_details]

data_qs.head()
# Out:
#                                      university  rank         country  \
# 0  Massachusetts Institute of Technology (MIT)      1   United States
# 1                           Stanford University     2   United States
# 2                            Harvard University     3   United States
# 3  California Institute of Technology (Caltech)     4   United States
# 4                       University of Cambridge     5  United Kingdom
#
#           region  international students  total students  \
# 0  North America                    3717           11067
# 1  North America                    3611           15878
# 2  North America                    5266           22429
# 3  North America                     647            2255
# 4         Europe                    6699           18770
#
#    international faculties  total faculties
# 0                     1679             2982
# 1                     2042             4285
# 2                     1311             4350
# 3                      350              953
# 4                     2278             5490

# %% [markdown]
# ### 2(a) Which are the best universities in term of ratio between faculty members and students

# %%
data_ratio_faculty_students = pd.DataFrame(data_qs[['university', 'country', 'region', 'total faculties','total students']])
data_ratio_faculty_students['ratio(%)'] = data_qs['total faculties']/data_qs['total students'] * 100
data_ratio_faculty_students = data_ratio_faculty_students.sort_values('ratio(%)', ascending=False)
data_ratio_faculty_students.head()
# Out:
#                                       university         country  \
# 3   California Institute of Technology (Caltech)   United States
# 15                               Yale University   United States
# 5                           University of Oxford  United Kingdom
# 4                        University of Cambridge  United Kingdom
# 16                      Johns Hopkins University   United States
#
#            region  total faculties  total students   ratio(%)
# 3   North America              953            2255  42.261641
# 15  North America             4940           12402  39.832285
# 5          Europe             6750           19720  34.229209
# 4          Europe             5490           18770  29.248801
# 16  North America             4462           16146  27.635328

# %% [markdown]
# ### 2(b) Which are the best universities in term of ratio of international students

# %%
data_ratio_inter_students = pd.DataFrame(data_qs[['university', 'country', 'region', 'international students','total students']])
data_ratio_inter_students['ratio(%)'] = data_qs['international students']/data_qs['total students'] * 100
data_ratio_inter_students = data_ratio_inter_students.sort_values('ratio(%)', ascending=False)
data_ratio_inter_students.head()
# Out:
#                                             university         country  \
# 34   London School of Economics and Political Scien...  United Kingdom
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)     Switzerland
# 7                              Imperial College London  United Kingdom
# 199                             Maastricht University      Netherlands
# 46                          Carnegie Mellon University   United States
#
#             region  international students  total students   ratio(%)
# 34          Europe                    6748            9760  69.139344
# 11          Europe                    5896           10343  57.004738
# 7           Europe                    8746           16090  54.356743
# 199         Europe                    8234           16385  50.253280
# 46   North America                    6385           13356  47.806229

# %% [markdown]
# ### 3(c) best university based on the ratio between faculty and students by country
#
# In this question, we show the university with the highest faculty-student ratio for every country

# %%
data_ratio_faculty_students.sort_values(['ratio(%)'], ascending=False).groupby('country').first()
# Out:
#                                                        university  \
# country
# Argentina                       Universidad de Buenos Aires (UBA)
# Australia                      The Australian National University
# Austria                                      University of Vienna
# Belgium                          Vrije Universiteit Brussel (VUB)
# Brazil                                  Universidade de São Paulo
# Canada                                        McMaster University
# Chile               Pontificia Universidad Católica de Chile (UC)
# China                                         Tsinghua University
# Denmark                           Technical University of Denmark
# Finland                                    University of Helsinki
# France                                        Ecole Polytechnique
# Germany                            Technical University of Munich
# Hong Kong                             The University of Hong Kong
# India                Indian Institute of Science (IISc) Bangalore
# Ireland          Trinity College Dublin, The University of Dublin
# Israel                         The Hebrew University of Jerusalem
# Italy                            Scuola Normale Superiore di Pisa
# Japan                                           Tohoku University
# Malaysia                                   Universiti Malaya (UM)
# Mexico          Instituto Tecnológico y de Estudios Superiores...
# Netherlands                                 Wageningen University
# New Zealand                            The University of Auckland
# Norway                                       University of Bergen
# Russia                          Lomonosov Moscow State University
# Saudi Arabia         King Fahd University of Petroleum & Minerals
# Singapore       Nanyang Technological University, Singapore (NTU)
# South Africa                              University of Cape Town
# South Korea     Pohang University of Science And Technology (P...
# Spain                              Universidad Autónoma de Madrid
# Sweden                          KTH Royal Institute of Technology
# Switzerland                                  University of Zurich
# Taiwan                           National Taiwan University (NTU)
# United Kingdom                               University of Oxford
# United States        California Institute of Technology (Caltech)
#
#                        region  total faculties  total students   ratio(%)
# country
# Argentina       Latin America            16421          122301  13.426710
# Australia             Oceania             1600           14442  11.078798
# Austria                Europe             3411           45967   7.420541
# Belgium                Europe             1792            9284  19.302025
# Brazil          Latin America             5582           65711   8.494773
# Canada          North America             3231           23702  13.631761
# Chile           Latin America             2260           27003   8.369440
# China                    Asia             5506           36300  15.168044
# Denmark                Europe             2117            8878  23.845461
# Finland                Europe             2645           22419  11.798028
# France                 Europe              649            3126  20.761356
# Germany                Europe             5850           38726  15.106130
# Hong Kong                Asia             3012           20214  14.900564
# India                    Asia              423            4071  10.390567
# Ireland                Europe             1249           14961   8.348372
# Israel                   Asia             2249           16531  13.604743
# Italy                  Europe               86             532  16.165414
# Japan                    Asia             3411           17827  19.133898
# Malaysia                 Asia             2755           17902  15.389342
# Mexico          Latin America             1822           13376  13.621411
# Netherlands            Europe             2277           12695  17.936195
# New Zealand           Oceania             2047           29641   6.905975
# Norway                 Europe             1513           10671  14.178615
# Russia                 Europe             6709           30233  22.190983
# Saudi Arabia             Asia             1062            6040  17.582781
# Singapore                Asia             4338           25738  16.854456
# South Africa           Africa             1733           19593   8.844996
# South Korea              Asia              664            3117  21.302534
# Spain                  Europe             2738           26511  10.327788
# Sweden                 Europe             1500           12658  11.850213
# Switzerland            Europe             4997           26065  19.171303
# Taiwan                   Asia             2807           32195   8.718745
# United Kingdom         Europe             6750           19720  34.229209
# United States   North America              953            2255  42.261641

# %%
data_ratio_faculty_students.sort_values(['ratio(%)'], ascending=False).groupby('country', as_index = False)\
.first().plot(y='ratio(%)', x=['country','university'], kind='bar',\
              grid=True, figsize=(10, 6), title='international_student_ratio')

# %% [markdown]
# ### 3(c) best university based on the ratio between international students and total students by country

# %%
data_ratio_inter_students.sort_values(['ratio(%)'], ascending=False).groupby('country').first()
# Out:
#                                                        university  \
# country
# Argentina                       Universidad de Buenos Aires (UBA)
# Australia                             The University of Melbourne
# Austria                                      University of Vienna
# Belgium                          Vrije Universiteit Brussel (VUB)
# Brazil                Universidade Estadual de Campinas (Unicamp)
# Canada                                          McGill University
# Chile               Pontificia Universidad Católica de Chile (UC)
# China                                           Peking University
# Denmark                           Technical University of Denmark
# Finland                                          Aalto University
# France                                        Ecole Polytechnique
# Germany                 Technische Universität Berlin (TU Berlin)
# Hong Kong                             The University of Hong Kong
# India                Indian Institute of Science (IISc) Bangalore
# Ireland          Trinity College Dublin, The University of Dublin
# Israel                         The Hebrew University of Jerusalem
# Italy           Scuola Superiore Sant'Anna Pisa di Studi Unive...
# Japan                               Tokyo Institute of Technology
# Malaysia                                   Universiti Malaya (UM)
# Mexico          Instituto Tecnológico y de Estudios Superiores...
# Netherlands                                Maastricht University
# New Zealand                            The University of Auckland
# Norway                                         University of Oslo
# Russia                          Lomonosov Moscow State University
# Saudi Arabia         King Fahd University of Petroleum & Minerals
# Singapore       Nanyang Technological University, Singapore (NTU)
# South Africa                              University of Cape Town
# South Korea                                    Hanyang University
# Spain                                    Universitat de Barcelona
# Sweden                                            Lund University
# Switzerland       Ecole Polytechnique Fédérale de Lausanne (EPFL)
# Taiwan                           National Taiwan University (NTU)
# United Kingdom  London School of Economics and Political Scien...
# United States                          Carnegie Mellon University
#
#                        region  international students  total students  \
# country
# Argentina       Latin America                   27109          122301
# Australia             Oceania                   18030           42182
# Austria                Europe                   14468           45967
# Belgium                Europe                    1853            9284
# Brazil          Latin America                     966           26572
# Canada          North America                    9540           28837
# Chile           Latin America                     991           27003
# China                    Asia                    7090           42136
# Denmark                Europe                    2098            8878
# Finland                Europe                    1831           12147
# France                 Europe                     924            3126
# Germany                Europe                    4494           22176
# Hong Kong                Asia                    8230           20214
# India                    Asia                      47            4071
# Ireland                Europe                    4311           14961
# Israel                   Asia                    1034           16531
# Italy                  Europe                     135             789
# Japan                    Asia                    1071            9832
# Malaysia                 Asia                    3476           17902
# Mexico          Latin America                    1412           13376
# Netherlands            Europe                    8234           16385
# New Zealand           Oceania                    8568           29641
# Norway                 Europe                    3667           24304
# Russia                 Europe                    5098           30233
# Saudi Arabia             Asia                     989            6040
# Singapore                Asia                    7251           25738
# South Africa           Africa                    3325           19593
# South Korea              Asia                    3397           23348
# Spain                  Europe                    6134           46002
# Sweden                 Europe                    6408           27786
# Switzerland            Europe                    5896           10343
# Taiwan                   Asia                    3152           32195
# United Kingdom         Europe                    6748            9760
# United States   North America                    6385           13356
#
#                  ratio(%)
# country
# Argentina       22.165804
# Australia       42.743350
# Austria         31.474754
# Belgium         19.959069
# Brazil           3.635406
# Canada          33.082498
# Chile            3.669963
# China           16.826467
# Denmark         23.631449
# Finland         15.073681
# France          29.558541
# Germany         20.265152
# Hong Kong       40.714356
# India            1.154507
# Ireland         28.814919
# Israel           6.254915
# Italy           17.110266
# Japan           10.893002
# Malaysia        19.416825
# Mexico          10.556220
# Netherlands     50.253280
# New Zealand     28.905907
# Norway          15.088051
# Russia          16.862369
# Saudi Arabia    16.374172
# Singapore       28.172352
# South Africa    16.970347
# South Korea     14.549426
# Spain           13.334203
# Sweden          23.061974
# Switzerland     57.004738
# Taiwan           9.790340
# United Kingdom  69.139344
# United States   47.806229

# %%
data_ratio_inter_students.sort_values(['ratio(%)'], ascending=False).groupby('country', as_index = False)\
.first().plot(y='ratio(%)', x=['country','university'], kind='bar',\
              grid=True, figsize=(10, 6), title='international_student_ratio')

# %% [markdown]
# ### 3(d) best university based on the ratio between faculty and student by region

# %%
data_ratio_faculty_students.sort_values(['ratio(%)'], ascending=False).groupby('region').first()
# Out:
#                                                       university  \
# region
# Africa                                   University of Cape Town
# Asia           Pohang University of Science And Technology (P...
# Europe                                      University of Oxford
# Latin America  Instituto Tecnológico y de Estudios Superiores...
# North America       California Institute of Technology (Caltech)
# Oceania                       The Australian National University
#
#                       country  total faculties  total students   ratio(%)
# region
# Africa           South Africa             1733           19593   8.844996
# Asia              South Korea              664            3117  21.302534
# Europe         United Kingdom             6750           19720  34.229209
# Latin America          Mexico             1822           13376  13.621411
# North America   United States              953            2255  42.261641
# Oceania             Australia             1600           14442  11.078798

# %%
data_ratio_faculty_students.sort_values(['ratio(%)'], ascending=False).groupby('region', as_index = False)\
.first().plot(y='ratio(%)', x=['region','university'], kind='bar',\
              grid=True, figsize=(10, 6), title='faculty_member_student_ratio')

# %% [markdown]
# ### 3(d) best university based on the ratio between international students and total students by region

# %%
data_ratio_inter_students.sort_values(['ratio(%)'], ascending=False).groupby('region').first()
# Out:
#                                                       university  \
# region
# Africa                                   University of Cape Town
# Asia                                 The University of Hong Kong
# Europe         London School of Economics and Political Scien...
# Latin America                  Universidad de Buenos Aires (UBA)
# North America                         Carnegie Mellon University
# Oceania                              The University of Melbourne
#
#                       country  international students  total students  \
# region
# Africa           South Africa                    3325           19593
# Asia                Hong Kong                    8230           20214
# Europe         United Kingdom                    6748            9760
# Latin America       Argentina                   27109          122301
# North America   United States                    6385           13356
# Oceania             Australia                   18030           42182
#
#                 ratio(%)
# region
# Africa         16.970347
# Asia           40.714356
# Europe         69.139344
# Latin America  22.165804
# North America  47.806229
# Oceania        42.743350

# %%
data_ratio_inter_students.sort_values(['ratio(%)'], ascending=False).groupby('region', as_index = False)\
.first().plot(y='ratio(%)', x=['country','university'], kind='bar',\
              grid=True, figsize=(10, 6), title='international_student_ratio')

# %% [markdown]
# # Part2. Times Ranking

# %% [markdown]
# ### 1. Obtain the 200 top-ranking universities in www.timeshighereducation.com (ranking 2018)

# %%
URL = 'https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json'
r = requests.get(URL)

universites_info = r.json()['data'][:200]

data_times = pd.DataFrame([(int)(university['rank'].replace('=','')) for university in universites_info], columns= ['rank'])
data_times['university'] = [university['name'] for university in universites_info]
data_times['country'] = [university['location'] for university in universites_info]
data_times['proportion of international students(%)'] = [(float)(university['stats_pc_intl_students'].replace('%','')) for university in universites_info]
data_times['student/staff (%)'] = [(float)(university['stats_student_staff_ratio']) for university in universites_info]

# %% [markdown]
# ### 2(a) best university based on the ratio between international students and total student

# %%
data_times.sort_values('proportion of international students(%)', ascending=False).head()
# Out:
#      rank                                        university         country  \
# 24     25  London School of Economics and Political Science  United Kingdom
# 178   179                          University of Luxembourg      Luxembourg
# 37     38          École Polytechnique Fédérale de Lausanne     Switzerland
# 7       8                           Imperial College London  United Kingdom
# 102   103                             Maastricht University     Netherlands
#
#      proportion of international students(%)  student/staff (%)
# 24                                      71.0               12.2
# 178                                     57.0               14.6
# 37                                      55.0               11.2
# 7                                       55.0               11.4
# 102                                     50.0               18.0

# %% [markdown]
# ### 2(b) best university based on the ratio between staff and student
# Because Times provides student-staff ratio, not staff-student ratio, so the lower the ratio is, the better the university is

# %%
data_times.sort_values('student/staff (%)')
# Out:
#      rank                                     university             country  \
# 105   105                          Vanderbilt University       United States
# 109   109                       University of Copenhagen             Denmark
# 12     13                       Johns Hopkins University       United States
# 11     12                                Yale University       United States
# 153   153                        University of Rochester       United States
# 97     98                               Emory University       United States
# 16     17                                Duke University       United States
# 114   115                            École Polytechnique              France
# 183   184               Scuola Normale Superiore di Pisa               Italy
# 101   100                       University of Pittsburgh       United States
# 185   186                            University of Miami       United States
# 135   136                           University of Zurich         Switzerland
# 152   153                Technical University of Denmark             Denmark
# 13     14                            Columbia University       United States
# 8       9                          University of Chicago       United States
# 10     10                     University of Pennsylvania       United States
# 2       3             California Institute of Technology       United States
# 88     89                              Dartmouth College       United States
# 45     46                            University of Tokyo               Japan
# 157   158                Case Western Reserve University       United States
# 193   194              Lomonosov Moscow State University  Russian Federation
# 3       3                            Stanford University       United States
# 50     50              Washington University in St Louis       United States
# 131   132  University of Science and Technology of China               China
# 6       7                           Princeton University       United States
# 181   182               École Normale Supérieure de Lyon              France
# 69     70                              Boston University       United States
# 20     21                         University of Michigan       United States
# 122   123                          Georgetown University       United States
# 4       5          Massachusetts Institute of Technology       United States
# ..    ...                                            ...                 ...
# 134   134                           Stockholm University              Sweden
# 132   133              Karlsruhe Institute of Technology             Germany
# 31     32                        University of Melbourne           Australia
# 84     85                  University of New South Wales           Australia
# 182   182               Hong Kong Polytechnic University           Hong Kong
# 112   113                        University of Göttingen             Germany
# 52     53        University of California, Santa Barbara       United States
# 156   155                                 Ulm University             Germany
# 195   196            Paris-Sorbonne University – Paris 4              France
# 80     80                              Monash University           Australia
# 166   165                         University of Würzburg             Germany
# 133   134                         University of Adelaide           Australia
# 64     65                       University of Queensland           Australia
# 106   107                               Ghent University             Belgium
# 155   155                                     TU Dresden             Germany
# 46     47                                      KU Leuven             Belgium
# 128   129               Université Catholique de Louvain             Belgium
# 93     94                         University of Tübingen             Germany
# 81     82                         University of Freiburg             Germany
# 173   173                          University of Münster             Germany
# 174   175                  Université Libre de Bruxelles             Belgium
# 144   145                          University of Cologne             Germany
# 40     41                 Technical University of Munich             Germany
# 61     62                  Humboldt University of Berlin             Germany
# 87     88                      Free University of Berlin             Germany
# 78     79                         RWTH Aachen University             Germany
# 163   162               University of Erlangen-Nuremberg             Germany
# 91     92                 Technical University of Berlin             Germany
# 124   125                         University of Mannheim             Germany
# 99    100                             University of Bonn             Germany
#
#      proportion of international students(%)  student/staff (%)
# 105                                     13.0                3.3
# 109                                     14.0                4.1
# 12                                      24.0                4.3
# 11                                      21.0                4.3
# 153                                     29.0                4.3
# 97                                      19.0                4.4
# 16                                      22.0                4.5
# 114                                     36.0                5.1
# 183                                      7.0                5.2
# 101                                     10.0                5.9
# 185                                     16.0                5.9
# 135                                     20.0                5.9
# 152                                     24.0                6.0
# 13                                      32.0                6.1
# 8                                       25.0                6.2
# 10                                      20.0                6.5
# 2                                       27.0                6.5
# 88                                      15.0                6.6
# 45                                      10.0                6.7
# 157                                     19.0                7.1
# 193                                     22.0                7.3
# 3                                       22.0                7.5
# 50                                      17.0                7.5
# 131                                      3.0                8.2
# 6                                       24.0                8.3
# 181                                     13.0                8.5
# 69                                      25.0                8.6
# 20                                      16.0                8.6
# 122                                     17.0                8.6
# 4                                       34.0                8.7
# ..                                       ...                ...
# 134                                      8.0               24.9
# 132                                     18.0               26.3
# 31                                      40.0               26.6
# 84                                      34.0               26.7
# 182                                     25.0               26.9
# 112                                     12.0               27.9
# 52                                      14.0               28.1
# 156                                     13.0               28.4
# 195                                     15.0               30.2
# 80                                      28.0               33.7
# 166                                      9.0               33.9
# 133                                     26.0               34.3
# 64                                      26.0               35.7
# 106                                     10.0               35.9
# 155                                     13.0               35.9
# 46                                      15.0               37.1
# 128                                     19.0               37.8
# 93                                      13.0               38.5
# 81                                      19.0               40.3
# 173                                      7.0               42.6
# 174                                     35.0               43.4
# 144                                     10.0               50.9
# 40                                      23.0               54.4
# 61                                      17.0               56.5
# 87                                      21.0               57.0
# 78                                      18.0               57.7
# 163                                     12.0               58.5
# 91                                      20.0               64.3
# 124                                     16.0               74.5
# 99                                      13.0               77.9
#
# [200 rows x 5 columns]

# %% [markdown]
# ### 2(c) best university based on the ratio between international students and total student in every country
# In ranking based on country and region, because Times only provides country, so we skip the part for ranking based on region

# %%
data_times.sort_values('proportion of international students(%)', ascending=False).groupby('country').first()
# Out:
#                     rank                                        university  \
# country
# Australia             32                           University of Melbourne
# Austria              165                              University of Vienna
# Belgium              175                     Université Libre de Bruxelles
# Canada                34                    University of British Columbia
# China                 27                                 Peking University
# Denmark              153                   Technical University of Denmark
# Finland              190                                  Aalto University
# France               115                               École Polytechnique
# Germany               41                    Technical University of Munich
# Hong Kong             40                           University of Hong Kong
# Ireland              117                            Trinity College Dublin
# Italy                155                        Scuola Superiore Sant’Anna
# Japan                 46                               University of Tokyo
# Luxembourg           179                          University of Luxembourg
# Netherlands          103                             Maastricht University
# New Zealand          192                            University of Auckland
# Norway               146                                University of Oslo
# Russian Federation   194                 Lomonosov Moscow State University
# Singapore             52       Nanyang Technological University, Singapore
# South Africa         171                           University of Cape Town
# South Korea          111                    Sungkyunkwan University (SKKU)
# Spain                147                Autonomous University of Barcelona
# Sweden                38                              Karolinska Institute
# Switzerland           38          École Polytechnique Fédérale de Lausanne
# Taiwan               198                        National Taiwan University
# United Kingdom        25  London School of Economics and Political Science
# United States         24                        Carnegie Mellon University
#
#                     proportion of international students(%)  student/staff (%)
# country
# Australia                                              40.0               26.6
# Austria                                                26.0               20.8
# Belgium                                                35.0               43.4
# Canada                                                 29.0               18.1
# China                                                  16.0                8.9
# Denmark                                                24.0                6.0
# Finland                                                20.0               20.2
# France                                                 36.0                5.1
# Germany                                                23.0               54.4
# Hong Kong                                              42.0               18.0
# Ireland                                                27.0               22.8
# Italy                                                  14.0               11.7
# Japan                                                  10.0                6.7
# Luxembourg                                             57.0               14.6
# Netherlands                                            50.0               18.0
# New Zealand                                            29.0               18.8
# Norway                                                 19.0               18.6
# Russian Federation                                     22.0                7.3
# Singapore                                              31.0               16.3
# South Africa                                           18.0               11.7
# South Korea                                            12.0               19.6
# Spain                                                  16.0               12.9
# Sweden                                                 19.0               10.9
# Switzerland                                            55.0               11.2
# Taiwan                                                  8.0               11.5
# United Kingdom                                         71.0               12.2
# United States                                          45.0               13.5

# %% [markdown]
# ### 2(c) best university based on the ratio between student and staff in every country

# %%
data_times.sort_values('student/staff (%)', ascending=False).groupby('country').first()
# Out:
#                     rank                               university  \
# country
# Australia             65                 University of Queensland
# Austria              165                     University of Vienna
# Belgium              175            Université Libre de Bruxelles
# Canada                78                      McMaster University
# China                169                       Nanjing University
# Denmark              109                        Aarhus University
# Finland              190                         Aalto University
# France               196      Paris-Sorbonne University – Paris 4
# Germany              100                       University of Bonn
# Hong Kong            182         Hong Kong Polytechnic University
# Ireland              117                   Trinity College Dublin
# Italy                155               Scuola Superiore Sant’Anna
# Japan                 74                         Kyoto University
# Luxembourg           179                 University of Luxembourg
# Netherlands           83                  University of Groningen
# New Zealand          192                   University of Auckland
# Norway               146                       University of Oslo
# Russian Federation   194        Lomonosov Moscow State University
# Singapore             22         National University of Singapore
# South Africa         171                  University of Cape Town
# South Korea          111           Sungkyunkwan University (SKKU)
# Spain                140                  Pompeu Fabra University
# Sweden               134                     Stockholm University
# Switzerland           95                      University of Basel
# Taiwan               198               National Taiwan University
# United Kingdom       130                     University of Exeter
# United States         53  University of California, Santa Barbara
#
#                     proportion of international students(%)  student/staff (%)
# country
# Australia                                              26.0               35.7
# Austria                                                26.0               20.8
# Belgium                                                35.0               43.4
# Canada                                                 15.0               24.7
# China                                                  10.0               14.2
# Denmark                                                12.0               14.3
# Finland                                                20.0               20.2
# France                                                 15.0               30.2
# Germany                                                13.0               77.9
# Hong Kong                                              25.0               26.9
# Ireland                                                27.0               22.8
# Italy                                                  14.0               11.7
# Japan                                                   8.0                8.7
# Luxembourg                                             57.0               14.6
# Netherlands                                            17.0               24.1
# New Zealand                                            29.0               18.8
# Norway                                                 19.0               18.6
# Russian Federation                                     22.0                7.3
# Singapore                                              30.0               17.0
# South Africa                                           18.0               11.7
# South Korea                                            12.0               19.6
# Spain                                                  12.0               20.8
# Sweden                                                  8.0               24.9
# Switzerland                                            27.0               17.7
# Taiwan                                                  8.0               11.5
# United Kingdom                                         28.0               17.5
# United States                                          14.0               28.1

# %% [markdown]
# # Combine the ranking in QS and Times

# %%
# change the name of the column "ranking" to avoid the conflict
data_qs = data_qs.rename(columns = {'rank':'rank_qs'})
data_times = data_times.rename(columns = {'rank':'rank_times'})

# %% [markdown]
# To combine them, we have to take care of the following things:
# 1. Some of letters are not in English, we should change all of them to English
# 2. QS use abbreviation such as EPFL, MIT ... etc, we have to remove them to make merging easier
# 3. Some names of universities are not English names, we need to filter them and find their correspondence manually

# %%
# 1. change the French/German letters into English letter
translationTable = str.maketrans("éàèùâêîôûçüäóãÉò", "eaeuaeioucuaoaEo")
data_qs['university'] = data_qs.university.apply(lambda x: x.translate(translationTable))
data_times['university'] = data_times.university.apply(lambda x: x.translate(translationTable))

# %% [markdown]
# In QS ranking, they use the non-English names for universities in non-English speaking region, we output the merged dataframe into csv file and compare the universities with blanks manually to find the exceptions. The following operations are making the university have the same name in both rankings

# %%
# 3. change the name
data_qs.loc[67, 'university'] = 'Heidelberg University'
data_qs.loc[87, 'university'] = 'Trinity College Dublin'
data_qs.loc[40, 'university'] = 'Korea Advanced Institute of Science and Technology'
data_qs.loc[6, 'university'] = 'University College London'
data_qs.loc[106, 'university'] = 'Karlsruhe Institute of Technology'
data_qs.loc[119, 'university'] = 'Humboldt University of Berlin'
data_qs.loc[124, 'university'] = 'Free University of Berlin'
data_qs.loc[129, 'university'] = 'University of Montreal'
data_qs.loc[130, 'university'] = 'Pierre and Marie Curie University'
data_qs.loc[143, 'university'] = 'Technical University of Berlin'
data_qs.loc[163, 'university'] = 'University of Tubingen'
data_qs.loc[170, 'university'] = 'University of Freiburg'
data_qs.loc[197, 'university'] = 'Autonomous University of Barcelona'
data_qs.loc[199, 'university'] = 'Maastricht University'


data_times.loc[9, 'university'] = 'ETH Zurich - Swiss Federal Institute of Technology'
data_times.loc[34, 'university'] = 'Ludwig-Maximilians-Universitat Munchen'
data_times.loc[35, 'university'] = "King's College London"
data_times.loc[50, 'university'] = "Washington University in St. Louis"
data_times.loc[56, 'university'] = 'University of North Carolina, Chapel Hill'
data_times.loc[63, 'university'] = 'Wageningen University'
data_times.loc[128, 'university'] = 'Universite catholique de Louvain'
data_times.loc[136, 'university'] = 'Pohang University of Science And Technology'
data_times.loc[155, 'university'] ='Technische Universitat Dresden'
data_times.loc[193, 'country'] = 'Russia'

# %% [markdown]
# Here we define two functions we use to remove:
#     1. abbreviation of university covered by parentheses: (abbreviation of university)
#     2. the string "The"

# %%
def remove_parentheses(name):
    ind1 = name.find('(')
    ind2 = name.find(')')
    if ind1 == -1:
        return name
    else:
        while ind2 + 1 < len(name):
            if name[ind2 + 1] == ' ':
                ind2 = ind2 + 1
            else:
                break
        if ind2 + 1 == len(name):
            while ind1 - 1 >= 0:
                if name[ind1 - 1] == ' ':
                    ind1 = ind1 - 1
                else:
                    break
        name = name.replace(name[ind1:ind2+1],'')
        return name
    
def remove_The(name):
    ind = name.find('The')
    if ind == -1:
        return name
    else:
        name = name.replace(name[0:4],'')
        return name

# remove parentheses
data_qs.university = data_qs.university.apply(lambda x: remove_parentheses(x))
data_times.university = data_times.university.apply(lambda x: remove_parentheses(x))
# remove "The"
data_qs.university = data_qs.university.apply(lambda x: remove_The(x))

# %% [markdown]
# Now, we merge two dataframes and omit the universities which doesn't exist in both rankings

# %%
data_merge = pd.merge(data_qs, data_times)
data_merge['proportion of international faculties (%)'] = data_merge['international faculties']/data_merge['total faculties'] * 100

# %%
# for university in data_times.university:
#     if university.find('College London') != -1:
#         print(university)
        
# for university in data_qs.university:
#     if university.find('College London') != -1:
#         print(university)
        
# data_qs1 = data_qs.copy()
# data_times1 = data_times.copy()

# %%
data_merge.to_csv('merge.csv')

# %% [markdown]
# # 3. Exploratory Data Analysis

# %% [markdown]
# #### Find useful insights in the data by performing an exploratory analysis. Can you find a strong correlation between any pair of variables in the dataset you just created? Example: when a university is strong in its international dimension, can you observe a consistency both for students and faculty members?

# %% [markdown]
# ### Relation between two variables
# We will use the following table to reveal some phenomenon

# %%
# inspect on the correlation coefficients in the data frame
data_merge.corr()
# Out:
#                                             rank_qs  international students  \
# rank_qs                                    1.000000               -0.233387
# international students                    -0.233387                1.000000
# total students                             0.021534                0.625608
# international faculties                   -0.489652                0.580730
# total faculties                           -0.303503                0.411640
# rank_times                                 0.685832               -0.231451
# proportion of international students(%)   -0.308411                0.408610
# student/staff (%)                          0.290609                0.225212
# proportion of international faculties (%) -0.354070                0.312591
#
#                                            total students  \
# rank_qs                                          0.021534
# international students                           0.625608
# total students                                   1.000000
# international faculties                          0.284751
# total faculties                                  0.590624
# rank_times                                      -0.113689
# proportion of international students(%)         -0.292548
# student/staff (%)                                0.319579
# proportion of international faculties (%)       -0.221324
#
#                                            international faculties  \
# rank_qs                                                  -0.489652
# international students                                    0.580730
# total students                                            0.284751
# international faculties                                   1.000000
# total faculties                                           0.639328
# rank_times                                               -0.343789
# proportion of international students(%)                   0.321102
# student/staff (%)                                        -0.071350
# proportion of international faculties (%)                 0.595311
#
#                                            total faculties  rank_times  \
# rank_qs                                          -0.303503    0.685832
# international students                            0.411640   -0.231451
# total students                                    0.590624   -0.113689
# international faculties                           0.639328   -0.343789
# total faculties                                   1.000000   -0.325068
# rank_times                                       -0.325068    1.000000
# proportion of international students(%)          -0.145673   -0.198852
# student/staff (%)                                -0.090130    0.071744
# proportion of international faculties (%)        -0.125892   -0.122335
#
#                                            proportion of international students(%)  \
# rank_qs                                                                  -0.308411
# international students                                                    0.408610
# total students                                                           -0.292548
# international faculties                                                   0.321102
# total faculties                                                          -0.145673
# rank_times                                                               -0.198852
# proportion of international students(%)                                   1.000000
# student/staff (%)                                                        -0.072219
# proportion of international faculties (%)                                 0.642269
#
#                                            student/staff (%)  \
# rank_qs                                             0.290609
# international students                              0.225212
# total students                                      0.319579
# international faculties                            -0.071350
# total faculties                                    -0.090130
# rank_times                                          0.071744
# proportion of international students(%)            -0.072219
# student/staff (%)                                   1.000000
# proportion of international faculties (%)          -0.006791
#
#                                            proportion of international faculties (%)
# rank_qs                                                                    -0.354070
# international students                                                      0.312591
# total students                                                             -0.221324
# international faculties                                                     0.595311
# total faculties                                                            -0.125892
# rank_times                                                                 -0.122335
# proportion of international students(%)                                     0.642269
# student/staff (%)                                                          -0.006791
# proportion of international faculties (%)                                   1.000000

# %% [markdown]
# #### Does the university with higher proportion of international students also have higher proportion of international faculties?
# In the result above, we could see the coefficient coefficient of % of international students and % of international faculties is 0.642269, which tells us that a university with more percentage of international students tends to have more percentage of international faculties (Like EPFL).
#
# However, we could also see some outliers in the plot. For example, there're some schools with lower proportion of international students but with higher proportion of international faculties, and it turns out to be the two universities in Switzerland: University of Zurich and University of Bern

# %%
data_merge.plot.scatter(x='proportion of international students(%)', y='proportion of international faculties (%)');
print('University with fewer than 20% of international students but with more than 50% of international faculties')
for university in data_merge.university[(data_merge['proportion of international faculties (%)'] > 50) & (data_merge['proportion of international students(%)'] <= 20)]:
    print(university)
# Out:
# University with fewer than 20% of international students but with more than 50% of international faculties
# University of Zurich
# University of Bern

# %% [markdown]
# #### Does higher # of international faculties help the ranking? (Not sure whether to put in report)
# We could see generally this is true, and now we observer the outlier (the one with very high ranking but with few number of international faculties). We could find generally there are two kinds of groups. The first group is the universities in Asia, and the other group is the universities in USA.

# %%
data_merge.plot.scatter(x='rank_qs', y='international faculties');
data_merge.university[(data_merge.rank_qs < 50) & (data_merge['international faculties'] < 500)]
# Out:
# 3                    California Institute of Technology
# 12                                 Princeton University
# 20                                      Duke University
# 28                                  University of Tokyo
# 35                                     Kyoto University
# 36                            Seoul National University
# 40    Korea Advanced Institute of Science and Techno...
# 45                           Carnegie Mellon University
# Name: university, dtype: object

# %% [markdown]
# #### Does the # of students move with # of faculties?
# The correlation between these two attributes is 0.59, and it reveals a natural result: If there are more students, we need more faculties. And there are some outliers with roughly 60000 students and fewer than 3000 faculties.

# %%
data_merge.plot.scatter(x='total students', y='total faculties');
print('University with fewer than 4000 faculties and more than 50000 students:')
for university in data_merge.university[(data_merge['total students'] > 50000) & (data_merge['total faculties'] < 4000)]:
    print(university)
# Out:
# University with fewer than 4000 faculties and more than 50000 students:
# Monash University
# University of Washington
# Texas A&M University

# %% [markdown]
# #### How does QS ranking and Times ranking differ?
# We could see an interesting phenomenon: There's no big difference within the top 30 universities in QS ranking and Times ranking (we could see an obvious line there), and after 30, the ranking starts to differ a lot.
#
# In the following we show the universities which are top 100 in QS but more than 150 in Times, and we can see the universities are mostly in Asia (Only KTH is in Europe). On the other hand, the universities which are top 100 in Times but more than 150 in QS are in Europe and USA.

# %%
data_merge.plot.scatter(x='rank_qs', y='rank_times');

print('University which is top 100 in QS but more than 150 in Times')
for university in data_merge.university[(data_merge.rank_qs < 100) & (data_merge.rank_times > 150)]:
    print(university)
print()
print('University which is top 100 in Times but more than 150 in QS')
for university in data_merge.university[(data_merge.rank_times < 100) & (data_merge.rank_qs > 150)]:
    print(university)
# Out:
# University which is top 100 in QS but more than 150 in Times
# Shanghai Jiao Tong University
# National Taiwan University
# University of Auckland
# Zhejiang University
# Lomonosov Moscow State University
# Hong Kong Polytechnic University
# KTH Royal Institute of Technology
#
# University which is top 100 in Times but more than 150 in QS
# University of Minnesota
# University of Tubingen
# University of California, Irvine
# Dartmouth College
# University of Freiburg

# %% [markdown]
# #### Does Times give worse ranking to universities in Asia?
# This question is naturally asked based on the observation above. We use rank_qs - rank_times to observe the result and we can see that only one university gets higher rank in Times: Peking University

# %%
(data_merge.rank_qs[data_merge.region == 'Asia'] - data_merge.rank_times[data_merge.region == 'Asia']).plot(x = 'QS ranking',\
                                                                                                           title = 'QS ranking - Times ranking')
print('Asia University with higher ranking in Times')
for university in data_merge.university[(data_merge.rank_qs > data_merge.rank_times) & (data_merge.region == 'Asia')]:
    print(university)
# Out:
# Asia University with higher ranking in Times
# Peking University

# %% [markdown]
# #### Calculate the proportions of university in top 200 by region

# %%
data_merge[data_merge.rank_qs < 200].groupby('region').size().plot('bar', title = 'Universities within 200')

# %% [markdown]
# #### Can you find the best university taking in consideration both rankings? Explain your approach.
